# %% [markdown]
# ##### Syntax
# Refers to the set of rules that defines the combinations of symbols that are considered to be correctly structured programs in a language. In simpler terms, syntax is about the correct arrangement of words and symbols in a code
#
# ##### Semantics
# Refers to the meaning or the interpretation of the symbols, characters, and commands in a language. It is about what the code is supposed to do when it runs.

# %%
## syntax rules in python

# %%
## 1. case sensitivity
name = 'Hello'
Name = 'hello'

print(name, Name)
# Out:
# Hello hello

# %%
## 2. indentation
age = 32
if age > 30:
    print("inside ", age)
print("outside ",age)
# Out:
# inside  32
# outside  32

# %%
## 3. line continuation
## use a backslash(\) to continue to the next line

total = 1+2+3+4+5+\
6+7+8+9

print(total)
# Out:
# 45

# %%
## 4. multiple statements in a single line

x = 5; y = 10; z = x + y
print(z)
# Out:
# 15

# %% [markdown]
# ##### Semantics

# %%
## variable assignment
age = 32 ## age is an integer
name = 'Hello' ## name is a string

print(age, type(age))
print(name, type(name))
# Out:
# 32 <class 'int'>
# Hello <class 'str'>

# %%
## type inference
var = 10
print(type(var))

var = 'Hello'
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## name error
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 ## name error
# ----> 2 a = b
#
# NameError: name 'b' is not defined

# %%
## example of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This won't be printed")
    print("This will print")

print("Outside if block")
# Out:
# Correct Indentation
# This will print
# Outside if block
