# %%
import os

cwd = os.getcwd()
print(cwd)
# Out:
# d:\tcs_genai_learn\6-file_handling

# %%
# creating a new directory
new_dir = "package"
os.mkdir(new_dir)
print(f'Directory {new_dir} created')
# Out:
# Directory package created

# %%
# listing files and directories
items = os.listdir('.')
print(items)
# Out:
# ['6.1-fileoperation.ipynb', '6.2-filepath.ipynb', 'destination.txt', 'eg.txt', 'example.bin', 'example.txt', 'package', 'source.txt']

# %%
# joining paths
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(), dir_name, file_name)
print(full_path)
# Out:
# d:\tcs_genai_learn\6-file_handling\folder\file.txt

# %%
path = 'example1.txt'
if os.path.exists(path):
    print(f'{path} exists')
else:
    print(f'{path} not exists')
# Out:
# example1.txt not exists

# %%
# check if the path is a file or directory
path = 'example.txt'

if os.path.isfile(path):
    print(f'{path} is a file')
elif os.path.isdir(path):
    print(f'{path} is a directory')
else:
    print(f'{path} is neither a file nor a directory')
# Out:
# example.txt is a file

# %%
# getting the absolute path
relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\tcs_genai_learn\6-file_handling\example.txt
