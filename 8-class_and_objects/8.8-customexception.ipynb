# %% [markdown]
# Custom Exception (Raise and Throw an exception)

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year = int(input("enter the dob"))
age = 2026 - year

try:
    if age <= 30 and age >=20:
        print("Age is valid, you can apply for the exam")
    else:
        raise dobException
except dobException:
    print('Sorry, the age should be greater than 20 or less than 30')
# Out:
# Sorry, the age should be greater than 20 or less than 30
