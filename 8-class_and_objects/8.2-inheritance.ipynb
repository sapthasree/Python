# %% [markdown]
# ##### Inheritance
#
# It is a fundamental concept in Object-Oriented programming (OOP) that allows a class to inherit attributes and methods from another class.

# %% [markdown]
# #### Single Inheritance

# %%
# parent class
class Car:
    def __init__(self, windows, doors, enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f'The person is driving {self.enginetype} car')

# %%
# parent class object
car1 = Car(3, 5, 'petrol')
car1.drive()
# Out:
# The person is driving petrol car

# %%
# child class
class Tesla(Car):
    def __init__(self, windows, doors, enginetype, is_selfdriving):
        super().__init__(windows, doors, enginetype)
        self.is_selfdriving = is_selfdriving

    def selfdrive(self):
        print(f'Tesla supports self-driving: {self.is_selfdriving}')

# %%
# child class object
tesla1 = Tesla(3,5,'petrol', True)
tesla1.selfdrive()

# parent class method
tesla1.drive()
# Out:
# Tesla supports self-driving: True
# The person is driving petrol car

# %% [markdown]
# #### Multiple Inheritance
#
# When a class inherit from more than one base class.

# %%
# base class 1
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print('subclass must implement this method')

# base class 2
class Pet:
    def __init__(self, owner):
        self.owner = owner

# derived class
class Dog(Animal, Pet):
    def __init__(self, name, owner):
        Animal.__init__(self, name)
        Pet.__init__(self, owner)

    def speak(self):
        return f'{self.name} say woof'

# %%
# create object
dog = Dog("Buddy", "Krish")
print(dog.speak())
print(f'Owner: {dog.owner}')
# Out:
# Buddy say woof
# Owner: Krish
